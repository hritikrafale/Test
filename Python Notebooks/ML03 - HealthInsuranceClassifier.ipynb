# %% [markdown]
# <img style="float: right;" width="120" src="https://s3.eu-west-1.amazonaws.com/neueda.conygre.com/pydata/images/neueda-logo.jpeg">
# <br><br><br>

# %% [markdown]
# Load some data from a csv file into Python so that the data can be used to train a model.
#
# This data contains information on customer's annual spend on health.

# %%
import pandas as pd

df_health = pd.read_csv('https://s3.eu-west-1.amazonaws.com/neueda.conygre.com/pydata/ml_fc/health_insurance_trimmed.csv', index_col=0)
df_health
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1      18    male  33.77         1     no  southeast   1725.5523
# 2      28    male  33.00         3     no  southeast   4449.4620
# 4      32    male  28.88         0     no  northwest   3866.8552
# 5      31  female  25.74         0     no  southeast   3756.6216
# 6      46  female  33.44         1     no  southeast   8240.5896
# ...   ...     ...    ...       ...    ...        ...         ...
# 1332   52  female  44.70         3     no  southwest  11411.6850
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
#
# [980 rows x 7 columns]

# %% [markdown]
# First change the output (health charges) to groups of numbers, i.e. categories:
#
# * less than \$3000
#
# * \\$3000 - \$5000
#
# * \\$5000 - \$10000
#
# * greater than \$10000.

# %%
# create a charge_category column filled with 0
df_health['charge_category'] = 0

# %%
# add a code to the charge_category column
df_health.loc[ df_health['charges'] < 3000 , 'charge_category'] = 0
df_health.loc[ (df_health['charges'] >= 3000) &  (df_health['charges'] < 5000), 'charge_category'] = 1
df_health.loc[ (df_health['charges'] >= 5000) &  (df_health['charges'] < 10000), 'charge_category'] = 2
df_health.loc[ df_health['charges'] >= 10000, 'charge_category'] = 3
df_health
# Out:
#       age  gender    bmi  children smoker     region     charges  \
# 1      18    male  33.77         1     no  southeast   1725.5523
# 2      28    male  33.00         3     no  southeast   4449.4620
# 4      32    male  28.88         0     no  northwest   3866.8552
# 5      31  female  25.74         0     no  southeast   3756.6216
# 6      46  female  33.44         1     no  southeast   8240.5896
# ...   ...     ...    ...       ...    ...        ...         ...
# 1332   52  female  44.70         3     no  southwest  11411.6850
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
#
#       charge_category
# 1                   0
# 2                   1
# 4                   1
# 5                   1
# 6                   2
# ...               ...
# 1332                3
# 1333                3
# 1334                0
# 1335                0
# 1336                0
#
# [980 rows x 8 columns]

# %% [markdown]
# Replace any words with numbers

# %%
# encode gender
df_health['gender_code'] = 0
df_health.loc[ df_health['gender'] == 'male', 'gender_code'] = 1
df_health
# Out:
#       age  gender    bmi  children smoker     region     charges  \
# 1      18    male  33.77         1     no  southeast   1725.5523
# 2      28    male  33.00         3     no  southeast   4449.4620
# 4      32    male  28.88         0     no  northwest   3866.8552
# 5      31  female  25.74         0     no  southeast   3756.6216
# 6      46  female  33.44         1     no  southeast   8240.5896
# ...   ...     ...    ...       ...    ...        ...         ...
# 1332   52  female  44.70         3     no  southwest  11411.6850
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
#
#       charge_category  gender_code
# 1                   0            1
# 2                   1            1
# 4                   1            1
# 5                   1            0
# 6                   2            0
# ...               ...          ...
# 1332                3            0
# 1333                3            1
# 1334                0            0
# 1335                0            0
# 1336                0            0
#
# [980 rows x 9 columns]

# %%
# encode smoker
df_health['smoker_code'] = 0
df_health.loc[ df_health['smoker'] == 'yes', 'smoker_code'] = 1
df_health
# Out:
#       age  gender    bmi  children smoker     region     charges  \
# 1      18    male  33.77         1     no  southeast   1725.5523
# 2      28    male  33.00         3     no  southeast   4449.4620
# 4      32    male  28.88         0     no  northwest   3866.8552
# 5      31  female  25.74         0     no  southeast   3756.6216
# 6      46  female  33.44         1     no  southeast   8240.5896
# ...   ...     ...    ...       ...    ...        ...         ...
# 1332   52  female  44.70         3     no  southwest  11411.6850
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
#
#       charge_category  gender_code  smoker_code
# 1                   0            1            0
# 2                   1            1            0
# 4                   1            1            0
# 5                   1            0            0
# 6                   2            0            0
# ...               ...          ...          ...
# 1332                3            0            0
# 1333                3            1            0
# 1334                0            0            0
# 1335                0            0            0
# 1336                0            0            0
#
# [980 rows x 10 columns]

# %% [markdown]
# Separate the dataframe into:
#
# * X: independent variable matrix  - this is the first 4 columns
# * y: dependant variable vector    - this is just the 'class' column

# %%
# create X and y from the appropriate columns
X = df_health.loc[:, ['age', 'gender_code', 'bmi', 'children', 'smoker_code']]

y = df_health[ ['charge_category'] ]

display(X.head())
display(y.head())
# Out:
#    age  gender_code    bmi  children  smoker_code
# 1   18            1  33.77         1            0
# 2   28            1  33.00         3            0
# 4   32            1  28.88         0            0
# 5   31            0  25.74         0            0
# 6   46            0  33.44         1            0
#    charge_category
# 1                0
# 2                1
# 4                1
# 5                1
# 6                2

# %% [markdown]
# Split our dataset into training and test sets

# %%
# use sklearn.model_selection train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Create an MLPClassifier object and train with the training data
#
# We could use any classification model e.g. you could try with the sklearn LogisticRegression model

# %%
# create and train the model
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000)
model.fit(X_train, y_train.values.ravel())
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000)

# %% [markdown]
# A quick check of accuracy with the test data

# %%
# print a confusion matrix - used to measure accuracy in classification models
from sklearn.metrics import confusion_matrix

predictions = model.predict( X_test )

print(confusion_matrix(y_test, predictions))
# Out:
# [[37  2  0  0]
#  [ 2 32  1  0]
#  [ 0  0 64  4]
#  [ 1  1  1 51]]

# %% [markdown]
# For demonstration, let's test with known data from the test dataset

# %%
# display some entries from the test data
display(y_test.head(2))
X_test.head(2)
# Out:
#       charge_category
# 416                 2
# 1234                2
#       age  gender_code    bmi  children  smoker_code
# 416    52            1  34.10         0            0
# 1234   45            0  27.83         2            0

# %%
# now let's predict for the above test data - is the prediction correct?
prediction = model.predict([[54, 0, 21.47, 3, 0]])

print(prediction)
# Out:
# [3]

# %% [markdown]
# We can use the predict_proba function to get the probability of being in each category for a particular prediction

# %%
# let's use the predict_proba function to get more useful prediction data
probabilities = model.predict_proba([[54, 1, 32.77, 0, 0]])

print(probabilities)

print(max(probabilities[0]))

print(list(probabilities[0]).index(max(probabilities[0])))
# Out:
# [[4.51287386e-10 1.04176783e-04 4.67145592e-01 5.32750230e-01]]
# 0.5327502302932807
# 3

# %% [markdown]
# Often, we want to use this trained model outside of the context of the notebook.
#
# We can save the model using a number of formats. The python joblib format is often used.

# %%
# import joblib and save trained model to file
import joblib

joblib.dump(model, 'health_charges_classifier_model.joblib')
# Out:
# ['health_charges_classifier_model.joblib']
